# %%
import numpy as np
import pandas as pd

# %%
soccer = pd.read_csv("Data/soccer.csv")

# %%
soccer.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
soccer.dtypes
# Out:
# name             object
# club             object
# age               int64
# position         object
# position_cat      int64
# market_value    float64
# page_views        int64
# fpl_value       float64
# fpl_sel          object
# fpl_points        int64
# region            int64
# nationality      object
# new_foreign       int64
# age_cat           int64
# club_id           int64
# big_club          int64
# new_signing       int64
# dtype: object

# %%
soccer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          465 non-null    object
#  1   club          465 non-null    object
#  2   age           465 non-null    int64
#  3   position      464 non-null    object
#  4   position_cat  465 non-null    int64
#  5   market_value  462 non-null    float64
#  6   page_views    465 non-null    int64
#  7   fpl_value     465 non-null    float64
#  8   fpl_sel       465 non-null    object
#  9   fpl_points    465 non-null    int64
#  10  region        465 non-null    int64
#  11  nationality   465 non-null    object
#  12  new_foreign   465 non-null    int64
#  13  age_cat       465 non-null    int64
#  14  club_id       465 non-null    int64
#  15  big_club      465 non-null    int64
#  16  new_signing   465 non-null    int64
# dtypes: float64(2), int64(10), object(5)
# ...

# %%
soccer.info(verbose=False, memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 190.7 KB

# %%
soccer.describe(include=np.number).round(2)
# Out:
#           age  position_cat  market_value  page_views  fpl_value  fpl_points  \
# count  465.00        465.00        462.00      465.00     465.00      465.00
# mean    26.78          2.18         11.13      771.55       5.45       57.54
# std      3.96          1.00         12.31      931.63       1.34       52.94
# min     17.00          1.00          0.05        3.00       4.00        0.00
# 25%     24.00          1.00          3.00      221.00       4.50        5.00
# 50%     27.00          2.00          7.00      461.00       5.00       51.00
# 75%     29.00          3.00         15.00      935.00       6.00       94.00
# max     38.00          4.00         75.00     7664.00      12.50      264.00
#
#        region  new_foreign  age_cat  club_id  big_club  new_signing
# count  465.00       465.00   465.00   465.00    465.00       465.00
# mean     1.99         0.03     3.20    10.25      0.31         0.14
# std      0.95         0.18     1.28     5.77      0.46         0.35
# ...

# %%
# Q. players having market_value greater than 40 Millions
mask = soccer["market_value"].gt(40)

# %%
soccer.loc[mask].head()
# Out:
#                name     club  age position  position_cat  market_value  \
# 0    Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1        Mesut Ozil  Arsenal   28       AM             1          50.0
# 96      Eden Hazard  Chelsea   26       LW             1          75.0
# 97      Diego Costa  Chelsea   28       CF             1          50.0
# 108  N%27Golo Kante  Chelsea   26       DM             2          50.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 0          4329       12.0  17.10%         264       3       Chile
# 1          4395        9.5   5.60%         167       2     Germany
# 96         4220       10.5   2.30%         224       2     Belgium
# 97         4454       10.0   3.00%         196       2       Spain
# 108        4042        5.0  13.80%          83       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        4        1         1            0
# ...

# %%
soccer.query("market_value > 40").head()
# Out:
#                name     club  age position  position_cat  market_value  \
# 0    Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1        Mesut Ozil  Arsenal   28       AM             1          50.0
# 96      Eden Hazard  Chelsea   26       LW             1          75.0
# 97      Diego Costa  Chelsea   28       CF             1          50.0
# 108  N%27Golo Kante  Chelsea   26       DM             2          50.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 0          4329       12.0  17.10%         264       3       Chile
# 1          4395        9.5   5.60%         167       2     Germany
# 96         4220       10.5   2.30%         224       2     Belgium
# 97         4454       10.0   3.00%         196       2       Spain
# 108        4042        5.0  13.80%          83       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        4        1         1            0
# ...

# %%
# positions
soccer["position"].unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
soccer["position"].unique().size
# Out:
# 14

# %%
# defender codes: LB, CB, RB
mask = (soccer["position"] == "LB") | (soccer["position"] == "CB") | (soccer["position"] == "RB")

# %%
soccer.loc[mask]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
soccer["position"].isin(["LB", "CB", "RB"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
soccer[soccer["position"].isin(["LB", "CB", "RB"])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
soccer.query('position in ["LB", "CB", "RB"]')
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
# Players with market value between 40 and 50 , exclusive
mask = soccer["market_value"].between(40,50, inclusive="neither")

# %%
soccer.loc[mask]
# Out:
#                   name             club  age position  position_cat  \
# 218  Philippe Coutinho        Liverpool   25       AM             1
# 246    Raheem Sterling  Manchester+City   22       LW             1
# 380          Dele Alli        Tottenham   21       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 218          45.0        2958        9.0  30.80%         171       3
# 246          45.0        2074        8.0   3.80%         149       1
# 380          45.0        4626        9.5  38.60%         225       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 218      Brazil            0        3       10         1            0
# 246     England            0        2       11         1            0
# 380     England            0        1       17         1            0

# %%
soccer.query("market_value > 40 and market_value < 50")
# Out:
#                   name             club  age position  position_cat  \
# 218  Philippe Coutinho        Liverpool   25       AM             1
# 246    Raheem Sterling  Manchester+City   22       LW             1
# 380          Dele Alli        Tottenham   21       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 218          45.0        2958        9.0  30.80%         171       3
# 246          45.0        2074        8.0   3.80%         149       1
# 380          45.0        4626        9.5  38.60%         225       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 218      Brazil            0        3       10         1            0
# 246     England            0        2       11         1            0
# 380     England            0        1       17         1            0

# %%
# Players with market value between 40 and 50 , inclusive
soccer.loc[soccer["market_value"].between(40,50)]
# Out:
#                     name               club  age position  position_cat  \
# 1             Mesut Ozil            Arsenal   28       AM             1
# 31   Alexandre Lacazette            Arsenal   26       CF             1
# 97           Diego Costa            Chelsea   28       CF             1
# 102     Thibaut Courtois            Chelsea   25       GK             4
# 108       N%27Golo Kante            Chelsea   26       DM             2
# 218    Philippe Coutinho          Liverpool   25       AM             1
# 219           Sadio Mane          Liverpool   25       LW             1
# 246      Raheem Sterling    Manchester+City   22       LW             1
# 263       Bernardo Silva    Manchester+City   22       RW             1
# 264        Romelu Lukaku  Manchester+United   24       CF             1
# 265         David de Gea  Manchester+United   26       GK             4
# 380            Dele Alli          Tottenham   21       CM             2
# ...

# %%
soccer.query("market_value >= 40 and market_value <= 50")
# Out:
#                     name               club  age position  position_cat  \
# 1             Mesut Ozil            Arsenal   28       AM             1
# 31   Alexandre Lacazette            Arsenal   26       CF             1
# 97           Diego Costa            Chelsea   28       CF             1
# 102     Thibaut Courtois            Chelsea   25       GK             4
# 108       N%27Golo Kante            Chelsea   26       DM             2
# 218    Philippe Coutinho          Liverpool   25       AM             1
# 219           Sadio Mane          Liverpool   25       LW             1
# 246      Raheem Sterling    Manchester+City   22       LW             1
# 263       Bernardo Silva    Manchester+City   22       RW             1
# 264        Romelu Lukaku  Manchester+United   24       CF             1
# 265         David de Gea  Manchester+United   26       GK             4
# 380            Dele Alli          Tottenham   21       CM             2
# ...

# %%
# players with age less than 26
soccer[soccer.age.lt(26)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
soccer.loc[soccer.age.le(25)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %% [markdown]
# ### Binary Operators
#
# ````
# | &
#
# XOR --> ^ alikes are True and Likes are False
# (two's) compliment --> ~  used as negation
#
# ````

# %%
True ^ False
# Out:
# True

# %%
True ^ True
# Out:
# False

# %%
False ^ False
# Out:
# False

# %%
True ^ (False | False & True) | False
# Out:
# True

# %%
~False
# Out:
# -1

# %%
~True
# Out:
# -2

# %%
bin(1)
# Out:
# '0b1'

# %%
bin(2)
# Out:
# '0b10'

# %%
format(1, "08b")
# Out:
# '00000001'

# %%
format(-2, "08b")
# Out:
# '-0000010'

# %%
# all left back players who are 25 or younger?
mask = ((soccer.position == "LB" )&
        (soccer.age <= 25))

# %%
soccer[mask]
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# ...

# %%
soccer.query("age <= 25 and position == 'LB'")
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# ...

# %%
soccer.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
mask_avg = soccer.apply(lambda x: x["market_value"]> (soccer["market_value"].mean())*2, axis=1)

# %%
soccer["nationality"]=="England"
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463     True
# 464    False
# Name: nationality, Length: 465, dtype: bool

# %%
soccer.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
soccer["page_views"] > 4000
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: page_views, Length: 465, dtype: bool

# %%
soccer["new_signing"] == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462    False
# 463     True
# 464    False
# Name: new_signing, Length: 465, dtype: bool

# %%
mask = (
    (soccer["nationality"]=="England") &
    (soccer.apply(lambda x: x["market_value"]> (soccer["market_value"].mean())*2, axis=1)) &
    ((soccer["page_views"] > 4000) ^ (soccer["new_signing"] == 1))
    
)

# %%
soccer[mask]
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %% [markdown]
# ### 2d Indexing

# %%
# Chelsea players and 23 years old or younger

# %%
mask = (soccer["club"] == "Chelsea") & \
(soccer["age"] <= 23)

# %%
soccer.loc[mask,["position", "market_value"]]
# Out:
#     position  market_value
# 110       CF          25.0
# 111       CB          15.0
# 112       LB           7.0
# 115       DM          16.0

# %%
soccer.query("club == 'Chelsea' and age <= 23")[["position", "market_value"]]
# Out:
#     position  market_value
# 110       CF          25.0
# 111       CB          15.0
# 112       LB           7.0
# 115       DM          16.0

# %%
## colums which start with letter p

# %%
soccer.filter(regex="^[(?i)p]", axis=1)
# Out:
#     position  position_cat  page_views
# 0         LW             1        4329
# 1         AM             1        4395
# 2         GK             4        1529
# 3         RW             1        2393
# 4         CB             3         912
# ..       ...           ...         ...
# 460       CM             2         288
# 461       LB             3         199
# 462       RB             3         198
# 463       CF             1         412
# 464       CF             1         214
#
# [465 rows x 3 columns]

# %%
p_cols = soccer.columns.str.startswith("p")

# %%
soccer.loc[:,p_cols]
# Out:
#     position  position_cat  page_views
# 0         LW             1        4329
# 1         AM             1        4395
# 2         GK             4        1529
# 3         RW             1        2393
# 4         CB             3         912
# ..       ...           ...         ...
# 460       CM             2         288
# 461       LB             3         199
# 462       RB             3         198
# 463       CF             1         412
# 464       CF             1         214
#
# [465 rows x 3 columns]

# %%
soccer.loc[mask,p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %% [markdown]
# ## Fancy Indexing

# %%
soccer.loc[[0,132],["name", "market_value"]]
# Out:
#         name  market_value
# 0    Chelsea          65.0
# 132  Chelsea           6.0

# %%
soccer.loc[450, ("age")]
# Out:
# 30

# %% [markdown]
# ## Sort By Index or Column

# %%
soccer.sort_index(ascending=False).head()
# Out:
#         name      club  age position  position_cat  market_value  page_views  \
# 464  Chelsea  West+Ham   27       CF             1          10.0         214
# 463  Chelsea  West+Ham   21       CF             1           1.0         412
# 462  Chelsea  West+Ham   23       RB             3           4.5         198
# 461  Chelsea  West+Ham   23       LB             3           7.0         199
# 460  Chelsea  West+Ham   21       CM             2           5.0         288
#
#      fpl_value fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  \
# 464        5.5   0.10%          12       4      Senegal            0        3
# 463        4.5   5.90%          16       1      England            0        1
# 462        4.5   0.30%          29       1      England            0        2
# 461        4.5   0.20%          34       4     Congo DR            0        2
# 460        4.5   0.40%          38       2  Switzerland            0        1
#
# ...

# %%
soccer.sort_values(by="age", ascending = False).head()
# Out:
#         name               club  age position  position_cat  market_value  \
# 136  Chelsea     Crystal+Palace   38       GK             4          0.25
# 35   Chelsea        Bournemouth   37       GK             4          1.00
# 424  Chelsea          West+Brom   37       CB             3          1.00
# 61   Chelsea  Brighton+and+Hove   36       RB             1          0.50
# 402  Chelsea            Watford   36       GK             4          1.00
#
#      page_views  fpl_value fpl_sel  fpl_points  region       nationality  \
# 136         188        4.0   2.00%           0       3         Argentina
# 35          436        4.5   6.90%         120       2            Poland
# 424         458        5.0  11.80%         131       2  Northern Ireland
# 61          215        4.5   0.40%           0       3         Argentina
# 402         439        4.5   2.20%         113       3            Brazil
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %%
soccer.sort_index(axis=1,ascending=False)
# Out:
#      region  position_cat position  page_views  new_signing  new_foreign  \
# 0         3             1       LW        4329            0            0
# 1         2             1       AM        4395            0            0
# 2         2             4       GK        1529            0            0
# 3         1             1       RW        2393            0            0
# 4         2             3       CB         912            0            0
# ..      ...           ...      ...         ...          ...          ...
# 460       2             2       CM         288            1            0
# 461       4             3       LB         199            1            0
# 462       1             3       RB         198            0            0
# 463       1             1       CF         412            1            0
# 464       4             1       CF         214            0            0
#
#         nationality     name  market_value  fpl_value fpl_sel  fpl_points  \
# ...

# %%
# set and reset index

# %%
soccer.set_index("name", inplace=True)

# %%
soccer.head()
# Out:
#             club  age position  position_cat  market_value  page_views  \
# name
# Chelsea  Arsenal   28       LW             1          65.0        4329
# Chelsea  Arsenal   28       AM             1          50.0        4395
# Chelsea  Arsenal   35       GK             4           7.0        1529
# Chelsea  Arsenal   28       RW             1          20.0        2393
# Chelsea  Arsenal   31       CB             3          22.0         912
#
#          fpl_value fpl_sel  fpl_points  region     nationality  new_foreign  \
# name
# Chelsea       12.0  17.10%         264       3           Chile            0
# Chelsea        9.5   5.60%         167       2         Germany            0
# Chelsea        5.5   5.90%         134       2  Czech Republic            0
# Chelsea        7.5   1.50%         122       1         England            0
# Chelsea        6.0   0.70%         121       2          France            0
#
#          age_cat  club_id  big_club  new_signing
# name
# ...

# %%
soccer.reset_index(inplace=True)

# %%
soccer.head()
# Out:
#       name     club  age position  position_cat  market_value  page_views  \
# 0  Chelsea  Arsenal   28       LW             1          65.0        4329
# 1  Chelsea  Arsenal   28       AM             1          50.0        4395
# 2  Chelsea  Arsenal   35       GK             4           7.0        1529
# 3  Chelsea  Arsenal   28       RW             1          20.0        2393
# 4  Chelsea  Arsenal   31       CB             3          22.0         912
#
#    fpl_value fpl_sel  fpl_points  region     nationality  new_foreign  \
# 0       12.0  17.10%         264       3           Chile            0
# 1        9.5   5.60%         167       2         Germany            0
# 2        5.5   5.90%         134       2  Czech Republic            0
# 3        7.5   1.50%         122       1         England            0
# 4        6.0   0.70%         121       2          France            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# ...

# %%
soccer = pd.read_csv("Data/soccer.csv")

# %%
soccer.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
#reindex()

# %%
players_lite = soccer.sample(5,axis=1).head(5)

# %%
players_lite
# Out:
#    new_signing  fpl_points               name  club_id  age
# 0            0         264     Alexis Sanchez        1   28
# 1            0         167         Mesut Ozil        1   28
# 2            0         134          Petr Cech        1   35
# 3            0         122       Theo Walcott        1   28
# 4            0         121  Laurent Koscielny        1   31

# %%
players_lite.reindex(index=[3,1,2,4,0], columns=["age", "name", "fpl_points","club_id","new_signing"])
# Out:
#    age               name  fpl_points  club_id  new_signing
# 3   28       Theo Walcott         122        1            0
# 1   28         Mesut Ozil         167        1            0
# 2   35          Petr Cech         134        1            0
# 4   31  Laurent Koscielny         121        1            0
# 0   28     Alexis Sanchez         264        1            0

# %%
sorted(soccer.columns.to_list())
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
sorted(soccer.columns)
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
soccer.iloc[[1,2,0,4],:].sort_index(axis=1)
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points fpl_sel  fpl_value  \
# 1   28        4         1  Arsenal        1         167   5.60%        9.5
# 2   35        6         1  Arsenal        1         134   5.90%        5.5
# 0   28        4         1  Arsenal        1         264  17.10%       12.0
# 4   31        4         1  Arsenal        1         121   0.70%        6.0
#
#    market_value               name     nationality  new_foreign  new_signing  \
# 1          50.0         Mesut Ozil         Germany            0            0
# 2           7.0          Petr Cech  Czech Republic            0            0
# 0          65.0     Alexis Sanchez           Chile            0            0
# 4          22.0  Laurent Koscielny          France            0            0
#
#    page_views position  position_cat  region
# 1        4395       AM             1       2
# 2        1529       GK             4       2
# 0        4329       LW             1       3
# ...

# %%
soccer.sort_values(by="age").head()
# Out:
#                        name               club  age position  position_cat  \
# 237            Ben Woodburn          Liverpool   17       LW             1
# 354              Josh Tymon         Stoke+City   18       LB             3
# 439           Jonathan Leko          West+Brom   18       RW             1
# 235  Trent Alexander-Arnold          Liverpool   18       RB             3
# 274         Marcus Rashford  Manchester+United   19       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 237           1.5        1241        4.5   0.10%           5       1
# 354           1.0         120        4.5   0.10%           9       1
# 439           1.5         169        4.5   0.20%          12       1
# 235           1.5         327        4.5   0.30%          15       2
# 274          18.0        3668        7.5   4.80%          76       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %%
soccer.age.idxmin() # index of minimum age
# Out:
# 237

# %%
soccer.loc[soccer.age.idxmin()].iloc[0]
# Out:
# 'Ben Woodburn'

# %%
soccer.age.argmin() # index of min age
# Out:
# 237

# %%
soccer.iloc[soccer.age.argmin()].loc["name"]
# Out:
# 'Ben Woodburn'

# %%
soccer.club.unique()
# Out:
# array(['Arsenal', 'Bournemouth', 'Brighton+and+Hove', 'Burnley',
#        'Chelsea', 'Crystal+Palace', 'Everton', 'Huddersfield',
#        'Leicester+City', 'Liverpool', 'Manchester+City',
#        'Manchester+United', 'Newcastle+United', 'Southampton',
#        'Stoke+City', 'Swansea', 'Tottenham', 'Watford', 'West+Brom',
#        'West+Ham'], dtype=object)

# %%
new_soc = soccer.set_index(keys="club")

# %%
new_soc.sort_index(inplace=True)

# %%
new_soc.head()
# Out:
#                       name  age position  position_cat  market_value  \
# club
# Arsenal     Alexis Sanchez   28       LW             1          65.0
# Arsenal         Mesut Ozil   28       AM             1          50.0
# Arsenal          Petr Cech   35       GK             4           7.0
# Arsenal       Theo Walcott   28       RW             1          20.0
# Arsenal  Laurent Koscielny   31       CB             3          22.0
#
#          page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# club
# Arsenal        4329       12.0  17.10%         264       3           Chile
# Arsenal        4395        9.5   5.60%         167       2         Germany
# Arsenal        1529        5.5   5.90%         134       2  Czech Republic
# Arsenal        2393        7.5   1.50%         122       1         England
# Arsenal         912        6.0   0.70%         121       2          France
#
#          new_foreign  age_cat  club_id  big_club  new_signing
# club
# ...

# %%
soccer.sort_values(by=["club", "market_value"], ascending=[True, False])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 31   Alexandre Lacazette   Arsenal   26       CF             1          40.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 451      Darren Randolph  West+Ham   30       GK             4           2.5
# 452        James Collins  West+Ham   33       CB             3           2.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...
